# %% [markdown]
# #
# # How to Evaluate the Regression Model Performance
# #

# %% [markdown]
# ![how%20to%20evaluate%20regression%20model%20performance-2.jpg](attachment:how%20to%20evaluate%20regression%20model%20performance-2.jpg)

# %% [markdown]
# ![how%20to%20evaluate%20regression%20model%20performance.jpg](attachment:how%20to%20evaluate%20regression%20model%20performance.jpg)

# %% [markdown]
# ![R2.jpg](attachment:R2.jpg)

# %% [markdown]
# ![regression%20evaluation%20metrics.jpg](attachment:regression%20evaluation%20metrics.jpg)
# #### All of these are loss functions because we want to minimize them.

# %% [markdown]
# ###
# ### Simple Explanation:
# ###
# ![mae,%20mse,%20rmse.jpg](attachment:mae,%20mse,%20rmse.jpg)
