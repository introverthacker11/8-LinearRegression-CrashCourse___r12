# %% [markdown]
# #
# # Assessing the performance of the model
# #

# %% [markdown]
# ![accessing%20performance%20of%20model.jpg](attachment:accessing%20performance%20of%20model.jpg)

# %% [markdown]
# ## How do we determine the best fit line?
# #### The line for which the error between the predicted values and the obserbed values is minimum is called the best fit line or the regression line. The errors are also called the residuals. The residuals can be visualized by the verticle line from the observed data value to the regression line.

# %% [markdown]
# ![accesing%20model%20performance.jpg](attachment:accesing%20model%20performance.jpg)
