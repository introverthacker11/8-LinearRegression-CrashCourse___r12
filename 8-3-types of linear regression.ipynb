# %% [markdown]
# #
# # Regression Types
# #

# %% [markdown]
# **It is of two types:**
# 1) Simple linear regression
# 2) Multiple linear regression.
#
# ## 1) Simple linear regression:
# It is characterized by a variable quantity.

# %% [markdown]
# ###
# ## 1) Simple Linear Regression
#
# ![simple%20linear%20regression.jpg](attachment:simple%20linear%20regression.jpg)

# %% [markdown]
# ![regression%20equation.jpg](attachment:regression%20equation.jpg)

# %% [markdown]
# ###
# ## 2) Multiple Linear Regression
#
# It(as the name suggests) is characterized by multiple independent variables (more than 1).While you discover the simplest fit line, you'll be able to adjust a polynomial or regression toward the mean. And these are called polynomial or regression toward mean.

# %% [markdown]
# ![multiple%20linear%20regression.jpg](attachment:multiple%20linear%20regression.jpg)

# %% [markdown]
# #### Useful links:
# https://youtu.be/zUQr6HAAKp4?si=mN6_r8RzSvSxcT_P
#
# https://youtu.be/owI7zxCqNY0?si=BzmkBCe_TbIZJZx9
